# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\Data_ML\Data_file_micro_crd.csv")
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111670  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228330  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df=df.drop(columns = ['Unnamed: 0','msisdn'])
df
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111670  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228330  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
df.isnull().sum()
# Out:
# label                   0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# pdate                   0
# dtype: int64

# %%
pd. set_option("display.max_rows", None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 35 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   aon                   209593 non-null  float64
#  2   daily_decr30          209593 non-null  float64
#  3   daily_decr90          209593 non-null  float64
#  4   rental30              209593 non-null  float64
#  5   rental90              209593 non-null  float64
#  6   last_rech_date_ma     209593 non-null  float64
#  7   last_rech_date_da     209593 non-null  float64
#  8   last_rech_amt_ma      209593 non-null  int64
#  9   cnt_ma_rech30         209593 non-null  int64
#  10  fr_ma_rech30          209593 non-null  float64
#  11  sumamnt_ma_rech30     209593 non-null  float64
#  12  medianamnt_ma_rech30  209593 non-null  float64
#  13  medianmarechprebal30  209593 non-null  float64
# ...

# %%
df.describe().iloc[:,:15]
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755200  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000       209593.00000      209593.000000
# mean     2692.581910    3483.406534         3755.84780        3712.202921
# std      4308.586781    5770.461279        53905.89223       53374.833430
# min    -23737.140000  -24720.580000          -29.00000         -29.000000
# ...

# %%
df.describe().iloc[:,15:]
# Out:
#         fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# count  209593.000000      209593.000000         209593.000000
# mean        7.716780       12396.218352           1864.595821
# std        12.590251       16857.793882           2081.680664
# min         0.000000           0.000000              0.000000
# 25%         0.000000        2317.000000            773.000000
# 50%         2.000000        7226.000000           1539.000000
# 75%         8.000000       16000.000000           1924.000000
# max        88.000000      953036.000000          55000.000000
#
#        medianmarechprebal90  cnt_da_rech30   fr_da_rech30  cnt_da_rech90  \
# count         209593.000000  209593.000000  209593.000000  209593.000000
# mean              92.025541     262.578110    3749.494447       0.041495
# std              369.215658    4183.897978   53885.414979       0.397556
# min             -200.000000       0.000000       0.000000       0.000000
# ...

# %%
df['pcircle'].value_counts()
# Out:
# UPW    209593
# Name: pcircle, dtype: int64

# %%
df['pdate'] = pd.to_datetime(df['pdate'], errors = 'coerce',format='%Y-%m-%d')
df['month'] = df['pdate'].dt.month
df['year'] = df['pdate'].dt.year
df['day'] = df['pdate'].dt.day

# %%
df=df.drop(columns = 'pdate')

# %%
df_corr = df.corr()
df_corr['label'].sort_values(ascending = False)
# Out:
# label                   1.000000
# cnt_ma_rech30           0.237331
# cnt_ma_rech90           0.236392
# sumamnt_ma_rech90       0.205793
# sumamnt_ma_rech30       0.202828
# amnt_loans90            0.199788
# amnt_loans30            0.197272
# cnt_loans30             0.196283
# daily_decr30            0.168298
# daily_decr90            0.166150
# medianamnt_ma_rech30    0.141490
# last_rech_amt_ma        0.131804
# medianamnt_ma_rech90    0.120855
# fr_ma_rech90            0.084385
# maxamnt_loans90         0.084144
# rental90                0.075521
# rental30                0.058085
# payback90               0.049183
# payback30               0.048336
# medianamnt_loans30      0.044589
# medianmarechprebal90    0.039300
# medianamnt_loans90      0.035747
# cnt_loans90             0.004733
# cnt_da_rech30           0.003827
# last_rech_date_ma       0.003728
# cnt_da_rech90           0.002999
# last_rech_date_da       0.001711
# fr_ma_rech30            0.001330
# ...

# %% [markdown]
# # EDA

# %%
plt.figure(figsize = (10,8))
sns.stripplot(x = 'label',y ='cnt_ma_rech30', data = df)
# Out:
# <AxesSubplot:xlabel='label', ylabel='cnt_ma_rech30'>

# %%
plt.figure(figsize = (10,8))
sns.stripplot(x = 'label',y ='cnt_ma_rech90', data = df)
# Out:
# <AxesSubplot:xlabel='label', ylabel='cnt_ma_rech90'>

# %%
plt.figure(figsize = (10,8))
sns.stripplot(x = 'label',y ='sumamnt_ma_rech90', data = df)
# Out:
# <AxesSubplot:xlabel='label', ylabel='sumamnt_ma_rech90'>

# %%
plt.figure(figsize = (10,8))
sns.stripplot(x = 'label',y ='sumamnt_ma_rech30', data = df)
# Out:
# <AxesSubplot:xlabel='label', ylabel='sumamnt_ma_rech30'>

# %%
plt.figure(figsize = (10,8))
sns.stripplot(x = 'label',y ='amnt_loans90', data = df)
# Out:
# <AxesSubplot:xlabel='label', ylabel='amnt_loans90'>

# %%
plt.figure(figsize = (10,8))
sns.stripplot(x = 'label',y ='amnt_loans30', data = df)
# Out:
# <AxesSubplot:xlabel='label', ylabel='amnt_loans30'>

# %%
plt.figure(figsize = (10,8))
sns.stripplot(x = 'label',y ='cnt_loans30', data = df)
# Out:
# <AxesSubplot:xlabel='label', ylabel='cnt_loans30'>

# %%
plt.figure(figsize = (10,8))
sns.stripplot(x = 'label',y ='daily_decr30', data = df)
# Out:
# <AxesSubplot:xlabel='label', ylabel='daily_decr30'>

# %%
plt.figure(figsize = (10,8))
sns.stripplot(x = 'label',y ='daily_decr90', data = df)
# Out:
# <AxesSubplot:xlabel='label', ylabel='daily_decr90'>

# %%
df = df.drop(columns = 'year')

# %%
plt.figure(figsize = (20,15))
sns.heatmap(df_corr, annot = True,cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x = 'daily_decr90',y = 'daily_decr30', data = df)
# Out:
# <AxesSubplot:xlabel='daily_decr90', ylabel='daily_decr30'>

# %%
sns.scatterplot(x = 'rental90',y = 'rental30', data = df)
# Out:
# <AxesSubplot:xlabel='rental90', ylabel='rental30'>

# %%
sns.scatterplot(x = 'cnt_ma_rech90',y = 'cnt_ma_rech30', data = df)
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech90', ylabel='cnt_ma_rech30'>

# %%
sns.scatterplot(x = 'sumamnt_ma_rech90',y = 'sumamnt_ma_rech30', data = df)
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech90', ylabel='sumamnt_ma_rech30'>

# %%
sns.scatterplot(x = 'last_rech_amt_ma',y = 'medianamnt_ma_rech90', data = df)
# Out:
# <AxesSubplot:xlabel='last_rech_amt_ma', ylabel='medianamnt_ma_rech90'>

# %%
sns.scatterplot(x = 'medianamnt_ma_rech30',y = 'medianamnt_ma_rech90', data = df)
# Out:
# <AxesSubplot:xlabel='medianamnt_ma_rech30', ylabel='medianamnt_ma_rech90'>

# %%
sns.scatterplot(x = 'amnt_loans30',y = 'amnt_loans90', data = df)
# Out:
# <AxesSubplot:xlabel='amnt_loans30', ylabel='amnt_loans90'>

# %%
sns.scatterplot(x = 'cnt_loans30',y = 'amnt_loans90', data = df)
# Out:
# <AxesSubplot:xlabel='cnt_loans30', ylabel='amnt_loans90'>

# %%
sns.scatterplot(x = 'medianamnt_loans30',y = 'medianamnt_loans90', data = df)
# Out:
# <AxesSubplot:xlabel='medianamnt_loans30', ylabel='medianamnt_loans90'>

# %%
sns.scatterplot(x = 'payback30',y = 'payback90', data = df)
# Out:
# <AxesSubplot:xlabel='payback30', ylabel='payback90'>

# %%
df1=df.drop(columns ='pcircle')
plt.figure(figsize = (20,80))
pltnum = 1
for i in df1:
    if pltnum<=36:
        plt.subplot(18,2,pltnum)
        sns.boxplot(x=i, color = 'cyan', orient = 'h',data=df)
        plt.xlabel(i, fontsize = 15)
    pltnum+=1
plt.tight_layout()

# %%
import sklearn 
from sklearn.preprocessing import LabelEncoder 

lencode=LabelEncoder()

df["pcircle"]=lencode.fit_transform(df["pcircle"])

# %%
from scipy.stats import zscore
z = np.abs(zscore(df[['aon','daily_decr90','rental90','last_rech_date_ma','cnt_ma_rech30','cnt_da_rech30','last_rech_date_ma']]))
z
# Out:
# array([[0.10357685, 0.27634619, 0.55858346, ..., 0.46476047, 0.06275935,
#         0.06963723],
#        [0.09776412, 0.5533797 , 0.03602034, ..., 0.69971849, 0.06275935,
#         0.06930331],
#        [0.10010243, 0.42903256, 0.44767352, ..., 0.69971849, 0.06275935,
#         0.06961867],
#        ...,
#        [0.09378769, 0.53319431, 0.93749981, ..., 0.24011359, 0.06275935,
#         0.06961867],
#        [0.08428915, 0.59455827, 0.4330386 , ..., 0.24011359, 0.06275935,
#         0.06963723],
#        [0.08628398, 0.14174607, 0.49427822, ..., 0.46476047, 0.06275935,
#         0.06943317]])

# %%
new_data = df[(z<2.8).all(axis = 1)]
print(new_data.shape)
print(df.shape)
# Out:
# (192794, 36)
# (209593, 36)

# %%
plt.figure(figsize = (30,120))
pltnum = 1
for i in new_data:
    if pltnum<=36:
        plt.subplot(18,2,pltnum)
        sns.kdeplot(x=i, color = 'cyan',data=new_data)
        plt.xlabel(i, fontsize = 25)
    pltnum+=1
plt.tight_layout()
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
new_data.skew()
# Out:
# label                   -2.183891
# aon                      0.945558
# daily_decr30             1.971144
# daily_decr90             2.000623
# rental30                 2.200720
# rental90                 2.118841
# last_rech_date_ma        3.036533
# last_rech_date_da       14.771100
# last_rech_amt_ma         3.186359
# cnt_ma_rech30            1.222543
# fr_ma_rech30            14.726795
# sumamnt_ma_rech30        3.168908
# medianamnt_ma_rech30     3.130302
# medianmarechprebal30    14.847538
# cnt_ma_rech90            1.751959
# fr_ma_rech90             2.215620
# sumamnt_ma_rech90        2.636287
# medianamnt_ma_rech90     3.392253
# medianmarechprebal90    46.596659
# cnt_da_rech30           54.081252
# fr_da_rech30            14.693527
# cnt_da_rech90           24.793890
# fr_da_rech90            29.662829
# cnt_loans30              1.819690
# amnt_loans30             1.952425
# maxamnt_loans30         17.786668
# medianamnt_loans30       4.500744
# ...

# %%
x = new_data.drop(columns = 'label')
y = new_data['label']
from sklearn.preprocessing import MinMaxScaler
scal = MinMaxScaler()
scd = scal.fit_transform(x)
x = pd.DataFrame(scd, columns = x.columns)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:400: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:401: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)

# %%
from sklearn.preprocessing import OrdinalEncoder, power_transform
tr_data = power_transform(x, method = 'yeo-johnson')
x = pd.DataFrame(tr_data, columns = x.columns)
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3237: RuntimeWarning: Degrees of freedom <= 0 for slice
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\utils\extmath.py:847: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\utils\extmath.py:689: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   result = op(x, *args, **kwargs)

# %%
x.skew()
# Out:
# aon                      0.138912
# daily_decr30             0.541138
# daily_decr90             0.565902
# rental30                -0.237343
# rental90                 0.078962
# last_rech_date_ma       -0.750206
# last_rech_date_da       13.966419
# last_rech_amt_ma         0.277605
# cnt_ma_rech30            0.135011
# fr_ma_rech30            13.989947
# sumamnt_ma_rech30        0.278974
# medianamnt_ma_rech30     0.208261
# medianmarechprebal30     9.073898
# cnt_ma_rech90            0.227047
# fr_ma_rech90             0.654211
# sumamnt_ma_rech90        0.319295
# medianamnt_ma_rech90     0.215753
# medianmarechprebal90    -0.164769
# cnt_da_rech30           15.669250
# fr_da_rech30            13.969584
# cnt_da_rech90            5.983559
# fr_da_rech90            15.896629
# cnt_loans30              0.271020
# amnt_loans30             0.286531
# maxamnt_loans30         13.677166
# medianamnt_loans30       3.417175
# cnt_loans90              3.608867
# ...

# %%
sns.countplot(x=y,data=y)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
X_train = x.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
x_over, y_over = sm.fit_resample(X_train,y)

# %%
sns.countplot(x=y_over,data=y_over)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
x_train, x_test, y_train,y_test = train_test_split(x_over,y_over, test_size = 0.33, random_state = 42)

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
rf_pred = rf.predict(x_test)
rf_score = accuracy_score(y_test,rf_pred)
rf_score
# Out:
# 0.9345226248846592

# %%
from sklearn.model_selection import cross_val_score
cv = cross_val_score(rf, x_over,y_over,cv = 5)
cv = cv.mean()
cv
# Out:
# 0.9354816204700016

# %%
from sklearn.metrics import roc_curve, auc
fpr,tpr, thresholds  = roc_curve(rf_pred, y_test)
roc_auc = auc(fpr,tpr)

plt.figure(figsize = (12,8))
plt.plot(fpr, tpr, lw=5, color = 'cyan',label = 'ROC Curve(area = %0.2f)'%roc_auc)
plt.plot([0,1],[0,1],lw =5, color ='black', linestyle = '--')
plt.xlim(0.0,1.0)
plt.ylim(0.0,1.0)
plt.xlabel('False positive rate', fontsize = 20)
plt.ylabel('True positive rate', fontsize  =20)
plt.title('ROC AUC Curve', fontsize = 30)
plt.legend(loc ='lower right', fontsize = 20)
plt.show()

# %%
print(classification_report(y_test, rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93     55192
#            1       0.94      0.93      0.93     55350
#
#     accuracy                           0.93    110542
#    macro avg       0.93      0.93      0.93    110542
# weighted avg       0.93      0.93      0.93    110542
